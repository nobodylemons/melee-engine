# %%
from google.colab import drive

drive.mount('/content/gdrive')
# %cd /content/gdrive/My Drive/git/melee-engine
# %cd ~
! if [ ! -d "./melee-engine" ] ; then git clone https://github.com/nobodylemons/melee-engine.git ; fi
# %cd melee-engine
! git checkout poc
! git pull
! pip install -U scikit-learn numpy pandas
! rsync -avzh /content/gdrive/MyDrive/training_data_csv /root/
# Out:
# Mounted at /content/gdrive
# /root
# Cloning into 'melee-engine'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 65 (delta 30), reused 53 (delta 22), pack-reused 0
# Receiving objects: 100% (65/65), 25.21 KiB | 12.61 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# /root/melee-engine
# Branch 'poc' set up to track remote branch 'poc' from 'origin'.
# Switched to a new branch 'poc'
# Already up to date.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 43.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 84.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 94.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 32.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
# ...

# %%
pip install rotary-embedding-torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.4 MB/s eta 0:00:00
# ...

# %%
# %cd ~/melee-engine
# !python create_encoder.py
# Out:
# /root/melee-engine
# 2023-10-15 19:31:51.074756: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-15 19:31:52.077426: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 11_03_04 Fox + Fox (YS).csv
# 04_22_43 [RUDE] Fox + [INFP] Fox (DL).csv
# 11_11_36 Fox + Fox (PS).csv
# 11_21_53 Fox + Fox (YI).csv
# 11_14_26 Fox + Fox (DL).csv
# 11_20_53 Fox + Fox (FD).csv
# 11_19_49 Fox + Fox (FoD).csv
# 01_41_44.754Z [EASY] Fox + [LITS] Fox (DL).csv
# 01_58_13.288Z [CUTE] Fox + [WS] Fox (BF).csv
# 11_06_35 Fox + [CUMB] Fox (BF).csv
# 10_46_35 Fox + Fox (PS).csv
# 10_56_50 Fox + Fox (FD).csv
# 11_25_41 Fox + Fox (FoD).csv
# 10_26_55 Fox + Fox (DL).csv
# 00_47_41.425Z Fox + Fox (PS).csv
# ...

# %%
# %cd ~/melee-engine

# !python train.py
# Out:
# /root/melee-engine
# 2023-10-15 19:32:04.022733: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-15 19:32:05.094563: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# 2023-10-15 19:32:10.739290: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...
